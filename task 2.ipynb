# %%
class FizzBuzz:
    def __init__(self, start, end):
        self.start = start
        self.end = end

    def play(self):
        for number in range(self.start, self.end + 1):
            if number % 3 == 0 and number % 5 == 0:
                print("Fizz Buzz")
            elif number % 3 == 0:
                print("Fizz")
            elif number % 5 == 0:
                print("Buzz")
            else:
                print(number)


# Creating Object of FizzBuzz Class
game = FizzBuzz(1, 100)
game.play()
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# Fizz Buzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# Fizz Buzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# Fizz Buzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# Fizz Buzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# Fizz Buzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# Fizz Buzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %%
class MovieBudgetAnalyzer:
    def __init__(self, movies):
        self.movies = movies

    def add_movies(self):
        count = int(input("How many movies would you like to add? "))
        for _ in range(count):
            name = input("Enter movie name: ")
            budget = int(input("Enter movie budget: "))
            self.movies.append((name, budget))
        print("\nNew movies added successfully!\n")

    def calculate_average_budget(self):
        total_budget = sum(budget for _, budget in self.movies)
        return total_budget / len(self.movies)

    def analyze_budgets(self):
        average = self.calculate_average_budget()
        print(f"\n🎬 Average Movie Budget: {average:,} USD\n")

        above_avg_count = 0
        print("📈 Movies Above Average Budget:\n")
        for name, budget in self.movies:
            if budget > average:
                difference = budget - average
                print(f"• {name} → {budget:,} USD  (📊 +{difference:,} above average)")
                above_avg_count += 1

        print(f"\n💡 Total movies above average budget: {above_avg_count}")

# ------- Main Program -------
movies = [
    ("Eternal Sunshine of the Spotless Mind", 20000000),
    ("Memento", 9000000),
    ("Requiem for a Dream", 4500000),
    ("Pirates of the Caribbean: On Stranger Tides", 379000000),
    ("Avengers: Age of Ultron", 365000000),
    ("Avengers: Endgame", 356000000),
    ("Incredibles 2", 200000000)
]

app = MovieBudgetAnalyzer(movies)
app.analyze_budgets()
# Out:
# 🎬 Average Movie Budget: 190,500,000.0 USD
#
# 📈 Movies Above Average Budget:
#
# • Pirates of the Caribbean: On Stranger Tides → 379,000,000 USD  (📊 +188,500,000.0 above average)
# • Avengers: Age of Ultron → 365,000,000 USD  (📊 +174,500,000.0 above average)
# • Avengers: Endgame → 356,000,000 USD  (📊 +165,500,000.0 above average)
# • Incredibles 2 → 200,000,000 USD  (📊 +9,500,000.0 above average)
#
# 💡 Total movies above average budget: 4
